# %% [markdown]
# ## Streprogen - Intermediate features

# %% [markdown]
# This notebook shows features of [streprogen](https://github.com/tommyod/streprogen), the Python strength program generator.
#
# - [GitHub repository](https://github.com/tommyod/streprogen)
# - [Python Package Index (PyPI)](https://pypi.org/project/streprogen/)
# - [Report issues or make feature requests](https://github.com/tommyod/streprogen/issues)
#
# Contributions to the code are welcome. :)

# %%
# !pip install streprogen matplotlib --quiet

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from streprogen import Program

# %% [markdown]
# ### Long term planning - a very simple setup
#
# Setting everything to **constant**, just to show how it works.

# %%
# We'll create a 16 week program, i.e. 4 months
duration = 16
weeks = list(range(1, duration))

from streprogen import progression_sinusoidal, progression_diffeq
import functools

plt.figure(figsize=(14, 4))

# ------------------------------------------------------

k = 0 # The non-linearity. k=0 is linear, as k gets higher progression becomes more non-linear
progression = functools.partial(progression_diffeq, k=0)

plt.subplot(1, 2, 1)
plt.title("Relationship between weeks and general strength progression")
plt.plot(weeks, progression(weeks, start_weight=100, final_weight=120, start_week=1, final_week=duration), '-o')
plt.xlabel("Weeks")
plt.ylabel("Weight")
plt.grid()

# ------------------------------------------------------

periods = 1 # The number of cycles (sine waves) in the 16 weeks
offset = 0 # The offset of the cycles 
scale = 0.00
scale_repetitions = functools.partial(progression_sinusoidal, start_weight=1, final_weight=1, start_week=1, 
                                    final_week=duration, periods=periods, scale=scale, offset=offset, k=0)


periods = 1 # The number of cycles (sine waves) in the 16 weeks
offset = 0 # The offset of the cycles 
scale = 0.00
scale_intensity = functools.partial(progression_sinusoidal, start_weight=1, final_weight=1, start_week=1, 
                                    final_week=duration, periods=periods, scale=scale, offset=offset, k=0)

plt.subplot(1, 2, 2)
plt.title("Rep and set scale factors")
plt.plot(weeks, scale_repetitions(weeks), '-o', label="Repetitions")
plt.plot(weeks, scale_intensity(weeks), '-o', label="Intensity")
plt.legend()
plt.xlabel("Weeks")
plt.ylabel("Scale factor (multiplicative)")
plt.ylim([0.75, 1.25])
plt.grid()

plt.tight_layout()

# %% [markdown]
# ### Long term planning - a more realistic setup
#
# Using periodicity and non-linearity.

# %%
# We'll create a 16 week program, i.e. 4 months
duration = 16
weeks = list(range(1, duration))

from streprogen import progression_sinusoidal
import functools

plt.figure(figsize=(14, 4))

# ------------------------------------------------------

periods = 4 # The number of cycles (sine waves) in the 16 weeks
scale = 0.015 # The amplitude of each cycle (i.e. height)
offset = 2 # The offset of the cycles 
k = 2 # The non-linearity. k=0 is linear, as k gets higher progression becomes more non-linear
progression = functools.partial(progression_sinusoidal, periods=periods, scale=scale, offset=offset, k=k)

plt.subplot(1, 2, 1)
plt.title("Relationship between weeks and general strength progression")
plt.plot(weeks, progression(weeks, start_weight=100, final_weight=120, start_week=1, final_week=duration), '-o')
plt.xlabel("Weeks")
plt.ylabel("Weight")
plt.grid()

# ------------------------------------------------------

periods = 2 # The number of cycles (sine waves) in the 16 weeks
scale = 0.2 # If the baseline is 25 reps/exercise, scale of 0.2 means we can go between 20 and 30
offset = 0 # The offset of the cycles 
scale_repetitions = functools.partial(progression_sinusoidal, start_weight=1, final_weight=1, start_week=1, 
                                    final_week=duration, periods=periods, scale=scale, offset=offset, k=0)

periods = 3 # The number of cycles (sine waves) in the 16 weeks
offset = 4 # The offset of the cycles 
scale = 0.04 # If the baseline is an intensity of 80%, scale of 0.04 means approx between 76 and 84
scale_intensity = functools.partial(progression_sinusoidal, start_weight=1, final_weight=1, start_week=1, 
                                    final_week=duration, periods=periods, scale=scale, offset=offset, k=0)

plt.subplot(1, 2, 2)
plt.title("Rep and set scale factors")
plt.plot(weeks, scale_repetitions(weeks), '-o', label="Repetitions")
plt.plot(weeks, scale_intensity(weeks), '-o', label="Intensity")
plt.legend()
plt.xlabel("Weeks")
plt.ylabel("Scale factor (multiplicative)")
plt.ylim([0.75, 1.25])
plt.grid()

plt.tight_layout()

# %% [markdown]
# ### Program setup

# %%
program = Program(
    name='AdvancedFeatures', # The name of the training program
    duration=duration, # The duration of the training program in weeks.
    units='kg', # Units for the weights, typically 'kg', 'lbs' or '' (empty)
    round_to=5, # What the weights are rounded to.
    
    # Use the functions above
    reps_per_exercise=25,
    rep_scaler_func=scale_repetitions,
    intensity=80,
    intensity_scaler_func=scale_intensity,
    progression_func=progression,
    
)


with program.Day("Day 1"):
    program.DynamicExercise(name="Bench", start_weight=80, min_reps=2, max_reps=8)
    program.DynamicExercise(name="Squats", start_weight=100, min_reps=2, max_reps=8)
    program.StaticExercise('Curls', '3 x 12')
    
with program.Day("Day 2"):
    program.DynamicExercise(name="Deadlifts", start_weight=100, min_reps=2, max_reps=8)
    program.DynamicExercise(name="Squats", start_weight=90, min_reps=2, max_reps=8)

# %% [markdown]
# ### Render the program

# %%
# Do the computations and render a program. Might take a few seconds.
program.render()

# %% [markdown]
# ### Print and save the program

# %%
print(program)
# Out:
# ----------------------------------------------------------------
# Program: AdvancedFeatures
#
# Program parameters
#   duration: 16
#   reps_per_exercise: 25
#   intensity: 80
#   units: kg
# ----------------------------------------------------------------
# Exercise information
#   Day 1
#    Bench        80kg -> 99.2kg
#     reps: [2, 8]   weekly inc.: 1.5%
#    Squats      100kg -> 124.0kg
#     reps: [2, 8]   weekly inc.: 1.5%
#    Curls       3 x 12
#   Day 2
#    Deadlifts   100kg -> 124.0kg
#     reps: [2, 8]   weekly inc.: 1.5%
#    Squats       90kg -> 111.6kg
#     reps: [2, 8]   weekly inc.: 1.5%
# ----------------------------------------------------------------
# Program
#  Week 1
#   Day 1
#    Bench       6 x 65kg   5 x 65kg   5 x 65kg   4 x 70kg   3 x 70kg
#    Squats      6 x 80kg   5 x 85kg   5 x 85kg   4 x 85kg   3 x 90kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 80kg   5 x 85kg   5 x 85kg   4 x 85kg   3 x 90kg
#    Squats      6 x 70kg   5 x 75kg   5 x 75kg   4 x 80kg   3 x 80kg
#
#  Week 2
#   Day 1
#    Bench       6 x 65kg   5 x 65kg   5 x 65kg   5 x 65kg   4 x 70kg
#    Squats      6 x 80kg   5 x 85kg   5 x 85kg   5 x 85kg   4 x 85kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 80kg   5 x 85kg   5 x 85kg   5 x 85kg   4 x 85kg
#    Squats      6 x 70kg   5 x 75kg   5 x 75kg   5 x 75kg   4 x 80kg
#
#  Week 3
#   Day 1
#    Bench       7 x 65kg   7 x 65kg   7 x 65kg   6 x 65kg   5 x 70kg   4 x 75kg
#    Squats      7 x 80kg   7 x 80kg   7 x 80kg   6 x 85kg   5 x 85kg   4 x 90kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 80kg   7 x 80kg   7 x 80kg   6 x 85kg   5 x 85kg   4 x 90kg
#    Squats      7 x 70kg   7 x 70kg   7 x 70kg   6 x 75kg   5 x 80kg   4 x 80kg
#
#  Week 4
#   Day 1
#    Bench       7 x 65kg   7 x 65kg   7 x 65kg   6 x 70kg   5 x 75kg
#    Squats      7 x 85kg   7 x 85kg   7 x 85kg   6 x 85kg   5 x 90kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 85kg   7 x 85kg   7 x 85kg   6 x 85kg   5 x 90kg
#    Squats      7 x 75kg   7 x 75kg   7 x 75kg   6 x 80kg   5 x 80kg
#
#  Week 5
#   Day 1
#    Bench       6 x 70kg   6 x 70kg   6 x 70kg   5 x 75kg   5 x 75kg
#    Squats      6 x 85kg   6 x 85kg   6 x 85kg   5 x 90kg   5 x 90kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 85kg   6 x 85kg   6 x 85kg   5 x 90kg   5 x 90kg
#    Squats      6 x 80kg   6 x 80kg   6 x 80kg   5 x 80kg   5 x 80kg
#
#  Week 6
#   Day 1
#    Bench       6 x 70kg   5 x 75kg   5 x 75kg   4 x 75kg   3 x 80kg
#    Squats      6 x 90kg   5 x 90kg   5 x 90kg   4 x 95kg   3 x 100kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 90kg   5 x 90kg   5 x 90kg   4 x 95kg   3 x 100kg
#    Squats      6 x 80kg   5 x 80kg   5 x 80kg   4 x 85kg   3 x 90kg
#
#  Week 7
#   Day 1
#    Bench       6 x 75kg   5 x 75kg   5 x 75kg   4 x 80kg
#    Squats      6 x 90kg   5 x 95kg   5 x 95kg   4 x 100kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 90kg   5 x 95kg   5 x 95kg   4 x 100kg
#    Squats      6 x 80kg   5 x 85kg   5 x 85kg   4 x 90kg
#
#  Week 8
#   Day 1
#    Bench       7 x 70kg   7 x 70kg   6 x 75kg   3 x 85kg
#    Squats      7 x 90kg   7 x 90kg   6 x 95kg   3 x 105kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 90kg   7 x 90kg   6 x 95kg   3 x 105kg
#    Squats      7 x 80kg   7 x 80kg   6 x 85kg   3 x 95kg
#
#  Week 9
#   Day 1
#    Bench       7 x 70kg   7 x 70kg   7 x 70kg   6 x 75kg   5 x 75kg
#    Squats      7 x 90kg   7 x 90kg   7 x 90kg   6 x 90kg   5 x 95kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 90kg   7 x 90kg   7 x 90kg   6 x 90kg   5 x 95kg
#    Squats      7 x 80kg   7 x 80kg   7 x 80kg   6 x 85kg   5 x 85kg
#
#  Week 10
#   Day 1
#    Bench       6 x 75kg   6 x 75kg   6 x 75kg   5 x 75kg   5 x 75kg
#    Squats      6 x 90kg   6 x 90kg   6 x 90kg   5 x 95kg   5 x 95kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 90kg   6 x 90kg   6 x 90kg   5 x 95kg   5 x 95kg
#    Squats      6 x 85kg   6 x 85kg   6 x 85kg   5 x 85kg   5 x 85kg
#
#  Week 11
#   Day 1
#    Bench       6 x 75kg   6 x 75kg   5 x 80kg   4 x 85kg   4 x 85kg   4 x 85kg   3 x 85kg
#    Squats      6 x 95kg   6 x 95kg   5 x 100kg  4 x 105kg  4 x 105kg  4 x 105kg  3 x 110kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 95kg   6 x 95kg   5 x 100kg  4 x 105kg  4 x 105kg  4 x 105kg  3 x 110kg
#    Squats      6 x 85kg   6 x 85kg   5 x 90kg   4 x 95kg   4 x 95kg   4 x 95kg   3 x 100kg
#
#  Week 12
#   Day 1
#    Bench       6 x 75kg   5 x 80kg   5 x 80kg   5 x 80kg   4 x 85kg
#    Squats      6 x 95kg   5 x 100kg  5 x 100kg  5 x 100kg  4 x 105kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 95kg   5 x 100kg  5 x 100kg  5 x 100kg  4 x 105kg
#    Squats      6 x 85kg   5 x 90kg   5 x 90kg   5 x 90kg   4 x 95kg
#
#  Week 13
#   Day 1
#    Bench       7 x 70kg   7 x 70kg   6 x 75kg   3 x 85kg
#    Squats      7 x 90kg   7 x 90kg   6 x 95kg   3 x 110kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 90kg   7 x 90kg   6 x 95kg   3 x 110kg
#    Squats      7 x 80kg   7 x 80kg   6 x 85kg   3 x 95kg
#
#  Week 14
#   Day 1
#    Bench       7 x 75kg   7 x 75kg   5 x 80kg
#    Squats      7 x 90kg   7 x 90kg   5 x 100kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 90kg   7 x 90kg   5 x 100kg
#    Squats      7 x 85kg   7 x 85kg   5 x 90kg
#
#  Week 15
#   Day 1
#    Bench       7 x 75kg   6 x 80kg   5 x 80kg   3 x 90kg
#    Squats      7 x 95kg   6 x 100kg  5 x 105kg  3 x 110kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   7 x 95kg   6 x 100kg  5 x 105kg  3 x 110kg
#    Squats      7 x 85kg   6 x 90kg   5 x 95kg   3 x 100kg
#
#  Week 16
#   Day 1
#    Bench       6 x 80kg   5 x 80kg   5 x 80kg   4 x 85kg   3 x 90kg
#    Squats      6 x 100kg  5 x 100kg  5 x 100kg  4 x 105kg  3 x 110kg
#    Curls       3 x 12
#
#   Day 2
#    Deadlifts   6 x 100kg  5 x 100kg  5 x 100kg  4 x 105kg  3 x 110kg
#    Squats      6 x 90kg   5 x 90kg   5 x 90kg   4 x 95kg   3 x 100kg
#
# ----------------------------------------------------------------

# %% [markdown]
# ### Export the program as `.html` or `.tex`, then to `.pdf`

# %% [markdown]
# A `.html` file can be printed directly from your browser, or printed to a `.pdf` from your browser.

# %%
# Save the program as a HTML file
with open('AdvancedFeatures.html', 'w', encoding='utf-8') as file:
    # Control table width (number of sets) by passing the 'table_width' argument
    file.write(program.to_html(table_width=6))

# %% [markdown]
# Use a `.tex` to generate `.pdf` if you have LaTEX installed, or use:
#
# - [latexbase.com](https://latexbase.com/) from your browser.

# %%
# If you have LaTeX installed on your system, you can render a program to .tex
# Alternatively, you can paste the LaTeX into: https://latexbase.com/
print(program.to_tex(table_width=6))
# Out:
# % -----------------------------------------------
# % Package imports
# % -----------------------------------------------
# \documentclass[11pt, a4paper]{article}% 'twoside' for printing
# \usepackage[utf8]{inputenc}% Allow input to be UTF-8
# \usepackage[margin = 2cm]{geometry}% May be used to set margins
#
# % -----------------------------------------------
# % Document start
# % -----------------------------------------------
#
# \begin{document}
# \large
#
# \section*{Program: AdvancedFeatures}
#
# This program was made using \verb|streprogen|,
# the Python strength program generator.
# The latest version can be found at \\
# \verb|https://pypi.python.org/pypi/streprogen/|.
#
#
# \section*{Program parameters}
# \begin{tabular}{l|l}
# 	\textbf{Parameter} & \textbf{Value} \\ \hline
# 	\verb|duration|             & 16 \\
# 	\verb|reps_per_exercise|    & 25 \\
# 	\verb|intensity|            & 80 \\
# 	\verb|units|                & kg
# \end{tabular}
#
#
# \section*{Exercise information}
# \begin{tabular}{llllll}
#     \textbf{Exercise} & \textbf{Start} & \textbf{End} & \textbf{Reps min}
#     & \textbf{Reps max} & \textbf{Weekly increase} \\ \hline
#       \textbf{ Day 1 } & & & & & \\ \hline
#         \hspace{0.5em}Bench & 80 kg &
#          99.2 kg & 2 & 8 &
#           1.5\%\\
#         \hspace{0.5em}Squats & 100 kg &
#          124.0 kg & 2 & 8 &
#           1.5\%\\
#        \hspace{0.5em}Curls & \multicolumn{ 5 }{l}{ 3 x 12 } \\
#       \textbf{ Day 2 } & & & & & \\ \hline
#         \hspace{0.5em}Deadlifts & 100 kg &
#          124.0 kg & 2 & 8 &
#           1.5\%\\
#         \hspace{0.5em}Squats & 90 kg &
#          111.6 kg & 2 & 8 &
#           1.5\%\\
# \end{tabular}
#
#
# \clearpage
# \section*{Program}
#  \subsection*{\hspace{0.25em} Week 1 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 65kg
#             & 5 x 65kg
#             & 5 x 65kg
#             & 4 x 70kg
#             & 3 x 70kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 80kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 4 x 85kg
#             & 3 x 90kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 80kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 4 x 85kg
#             & 3 x 90kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 70kg
#             & 5 x 75kg
#             & 5 x 75kg
#             & 4 x 80kg
#             & 3 x 80kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 2 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 65kg
#             & 5 x 65kg
#             & 5 x 65kg
#             & 5 x 65kg
#             & 4 x 70kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 80kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 4 x 85kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 80kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 4 x 85kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 70kg
#             & 5 x 75kg
#             & 5 x 75kg
#             & 5 x 75kg
#             & 4 x 80kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 3 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 65kg
#             & 7 x 65kg
#             & 7 x 65kg
#             & 6 x 65kg
#             & 5 x 70kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 75kg
#             &
#             &
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 80kg
#             & 7 x 80kg
#             & 7 x 80kg
#             & 6 x 85kg
#             & 5 x 85kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 90kg
#             &
#             &
#             &
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 80kg
#             & 7 x 80kg
#             & 7 x 80kg
#             & 6 x 85kg
#             & 5 x 85kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 90kg
#             &
#             &
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 70kg
#             & 7 x 70kg
#             & 7 x 70kg
#             & 6 x 75kg
#             & 5 x 80kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 80kg
#             &
#             &
#             &
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 4 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 65kg
#             & 7 x 65kg
#             & 7 x 65kg
#             & 6 x 70kg
#             & 5 x 75kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 85kg
#             & 7 x 85kg
#             & 7 x 85kg
#             & 6 x 85kg
#             & 5 x 90kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 85kg
#             & 7 x 85kg
#             & 7 x 85kg
#             & 6 x 85kg
#             & 5 x 90kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 75kg
#             & 7 x 75kg
#             & 7 x 75kg
#             & 6 x 80kg
#             & 5 x 80kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 5 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 70kg
#             & 6 x 70kg
#             & 6 x 70kg
#             & 5 x 75kg
#             & 5 x 75kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 85kg
#             & 6 x 85kg
#             & 6 x 85kg
#             & 5 x 90kg
#             & 5 x 90kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 85kg
#             & 6 x 85kg
#             & 6 x 85kg
#             & 5 x 90kg
#             & 5 x 90kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 80kg
#             & 6 x 80kg
#             & 6 x 80kg
#             & 5 x 80kg
#             & 5 x 80kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 6 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 70kg
#             & 5 x 75kg
#             & 5 x 75kg
#             & 4 x 75kg
#             & 3 x 80kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 90kg
#             & 5 x 90kg
#             & 5 x 90kg
#             & 4 x 95kg
#             & 3 x 100kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 90kg
#             & 5 x 90kg
#             & 5 x 90kg
#             & 4 x 95kg
#             & 3 x 100kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 80kg
#             & 5 x 80kg
#             & 5 x 80kg
#             & 4 x 85kg
#             & 3 x 90kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 7 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 75kg
#             & 5 x 75kg
#             & 5 x 75kg
#             & 4 x 80kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 90kg
#             & 5 x 95kg
#             & 5 x 95kg
#             & 4 x 100kg
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 90kg
#             & 5 x 95kg
#             & 5 x 95kg
#             & 4 x 100kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 80kg
#             & 5 x 85kg
#             & 5 x 85kg
#             & 4 x 90kg
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 8 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 70kg
#             & 7 x 70kg
#             & 6 x 75kg
#             & 3 x 85kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 95kg
#             & 3 x 105kg
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 95kg
#             & 3 x 105kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 80kg
#             & 7 x 80kg
#             & 6 x 85kg
#             & 3 x 95kg
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 9 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 70kg
#             & 7 x 70kg
#             & 7 x 70kg
#             & 6 x 75kg
#             & 5 x 75kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 90kg
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 90kg
#             & 5 x 95kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 90kg
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 90kg
#             & 5 x 95kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 80kg
#             & 7 x 80kg
#             & 7 x 80kg
#             & 6 x 85kg
#             & 5 x 85kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 10 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 75kg
#             & 6 x 75kg
#             & 6 x 75kg
#             & 5 x 75kg
#             & 5 x 75kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 90kg
#             & 6 x 90kg
#             & 6 x 90kg
#             & 5 x 95kg
#             & 5 x 95kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 90kg
#             & 6 x 90kg
#             & 6 x 90kg
#             & 5 x 95kg
#             & 5 x 95kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 85kg
#             & 6 x 85kg
#             & 6 x 85kg
#             & 5 x 85kg
#             & 5 x 85kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 11 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 75kg
#             & 6 x 75kg
#             & 5 x 80kg
#             & 4 x 85kg
#             & 4 x 85kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 85kg
#             & 3 x 85kg
#             &
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 95kg
#             & 6 x 95kg
#             & 5 x 100kg
#             & 4 x 105kg
#             & 4 x 105kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 105kg
#             & 3 x 110kg
#             &
#             &
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 95kg
#             & 6 x 95kg
#             & 5 x 100kg
#             & 4 x 105kg
#             & 4 x 105kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 105kg
#             & 3 x 110kg
#             &
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 85kg
#             & 6 x 85kg
#             & 5 x 90kg
#             & 4 x 95kg
#             & 4 x 95kg
#             \\
#
#
#             \hspace{0.75em}
#             & 4 x 95kg
#             & 3 x 100kg
#             &
#             &
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 12 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 75kg
#             & 5 x 80kg
#             & 5 x 80kg
#             & 5 x 80kg
#             & 4 x 85kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 95kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 4 x 105kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 95kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 4 x 105kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 85kg
#             & 5 x 90kg
#             & 5 x 90kg
#             & 5 x 90kg
#             & 4 x 95kg
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 13 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 70kg
#             & 7 x 70kg
#             & 6 x 75kg
#             & 3 x 85kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 95kg
#             & 3 x 110kg
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 90kg
#             & 7 x 90kg
#             & 6 x 95kg
#             & 3 x 110kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 80kg
#             & 7 x 80kg
#             & 6 x 85kg
#             & 3 x 95kg
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 14 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 75kg
#             & 7 x 75kg
#             & 5 x 80kg
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 90kg
#             & 7 x 90kg
#             & 5 x 100kg
#             &
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 90kg
#             & 7 x 90kg
#             & 5 x 100kg
#             &
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 85kg
#             & 7 x 85kg
#             & 5 x 90kg
#             &
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 15 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 7 x 75kg
#             & 6 x 80kg
#             & 5 x 80kg
#             & 3 x 90kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 95kg
#             & 6 x 100kg
#             & 5 x 105kg
#             & 3 x 110kg
#             &
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 7 x 95kg
#             & 6 x 100kg
#             & 5 x 105kg
#             & 3 x 110kg
#             &
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 7 x 85kg
#             & 6 x 90kg
#             & 5 x 95kg
#             & 3 x 100kg
#             &
#             \\
#
#
#   \end{tabular}
#
#
#  \subsection*{\hspace{0.25em} Week 16 }
#   \subsection*{\hspace{0.5em} Day 1 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Bench
#             & 6 x 80kg
#             & 5 x 80kg
#             & 5 x 80kg
#             & 4 x 85kg
#             & 3 x 90kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 100kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 4 x 105kg
#             & 3 x 110kg
#             \\
#
#
#    \hspace{0.75em} Curls &  \multicolumn{ 5 }{l}{ 3 x 12 } \\
#   \end{tabular}
#
#   \subsection*{\hspace{0.5em} Day 2 }
#
#
#   \begin{tabular}{l|lllll}
#   \hspace{0.75em} \textbf{Exercise} & \multicolumn{ 5 }{l}{ \textbf{Sets / reps} } \\ \hline
#
#             \hspace{0.75em} Deadlifts
#             & 6 x 100kg
#             & 5 x 100kg
#             & 5 x 100kg
#             & 4 x 105kg
#             & 3 x 110kg
#             \\
#
#
#             \hspace{0.75em} Squats
#             & 6 x 90kg
#             & 5 x 90kg
#             & 5 x 90kg
#             & 4 x 95kg
#             & 3 x 100kg
#             \\
#
#
#   \end{tabular}
#
#
#
# \end{document}
